# %% [markdown]
# # Review Rating Predictor for Amazon
# by Allen Wang

# %% [markdown]
# Create a review rating predictor on an Amazon Product Dataset and also to explore the relationship between variables and reviews and ratings on products.

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import statsmodels.api as sm
import datetime as dt

#Show plots in line
# %matplotlib inline

# %%
#Suppress warnings import warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
df = pd.read_csv('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv')

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 4  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 3  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 4  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 1   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 2   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 3   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 4   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  ... reviews.didPurchase  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 1  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 2  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 3  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 4  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
#
#   reviews.doRecommend reviews.id reviews.numHelpful reviews.rating  \
# 0                 NaN        NaN                NaN              3
# 1                 NaN        NaN                NaN              4
# 2                 NaN        NaN                NaN              5
# 3                 NaN        NaN                NaN              5
# 4                 NaN        NaN                NaN              5
#
#                                   reviews.sourceURLs  \
# 0  https://www.amazon.com/product-reviews/B00QWO9...
# 1  https://www.amazon.com/product-reviews/B00QWO9...
# 2  https://www.amazon.com/product-reviews/B00QWO9...
# 3  https://www.amazon.com/product-reviews/B00QWO9...
# 4  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
# 2  Well they are not Duracell but for the price i...
# 3  Seem to work as well as name brand batteries a...
# 4  These batteries are very long lasting the pric...
#
#                                        reviews.title  reviews.username  \
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
# 2  ... are not Duracell but for the price i am ha...  BySharon Lambert
# 3  ... as well as name brand batteries at a much ...     Bymark sexson
# 4  ... batteries are very long lasting the price ...           Bylinda
#
#                                           sourceURLs
# 0  https://www.barcodable.com/upc/841710106442,ht...
# 1  https://www.barcodable.com/upc/841710106442,ht...
# 2  https://www.barcodable.com/upc/841710106442,ht...
# 3  https://www.barcodable.com/upc/841710106442,ht...
# 4  https://www.barcodable.com/upc/841710106442,ht...
#
# [5 rows x 24 columns]

# %% [markdown]
# Data Cleanup

# %%
df.count()
# Out:
# id                     28332
# dateAdded              28332
# dateUpdated            28332
# name                   28332
# asins                  28332
# brand                  28332
# categories             28332
# primaryCategories      28332
# imageURLs              28332
# keys                   28332
# manufacturer           28332
# manufacturerNumber     28332
# reviews.date           28332
# reviews.dateSeen       28332
# reviews.didPurchase        9
# reviews.doRecommend    16086
# reviews.id                41
# reviews.numHelpful     16115
# reviews.rating         28332
# reviews.sourceURLs     28332
# reviews.text           28332
# reviews.title          28332
# reviews.username       28332
# sourceURLs             28332
# dtype: int64

# %% [markdown]
# It seems that there are a lot of missing values for the review.didPurchase and the reviews.id columns. It is best to just remove those columns as they won't serve a significant purpose for EDA.

# %%
df = df.drop('reviews.id', axis = 1)
df = df.drop('reviews.didPurchase', axis = 1)

# %%
df.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'name', 'asins', 'brand',
#        'categories', 'primaryCategories', 'imageURLs', 'keys', 'manufacturer',
#        'manufacturerNumber', 'reviews.date', 'reviews.dateSeen',
#        'reviews.doRecommend', 'reviews.numHelpful', 'reviews.rating',
#        'reviews.sourceURLs', 'reviews.text', 'reviews.title',
#        'reviews.username', 'sourceURLs'],
#       dtype='object')

# %% [markdown]
# Converting all the date strings to datetime objects for the purpose of easier computation in the future.

# %%
#convert all dates to datetime objects
df.head()
df['dateAdded'] = pd.to_datetime(df['dateAdded'])
df['dateUpdated'] = pd.to_datetime(df['dateUpdated'])
df['reviews.date'] = pd.to_datetime(df['reviews.date'])
#review.dateSeen has multiple dates in each entry, however the column is useless

# %%
df['dateAdded'].dtype,df['dateUpdated'].dtype,df['reviews.date'].dtype
# Out:
# (datetime64[ns, UTC], datetime64[ns, UTC], datetime64[ns, UTC])

# %%
#The reviews.dateSeen columnn is unnecessary information because it
#information when the review was seen by Datafini, the datacollectors
df = df.drop('reviews.dateSeen', axis = 1)

# %%
df.dtypes
# Out:
# id                                  object
# dateAdded              datetime64[ns, UTC]
# dateUpdated            datetime64[ns, UTC]
# name                                object
# asins                               object
# brand                               object
# categories                          object
# primaryCategories                   object
# imageURLs                           object
# keys                                object
# manufacturer                        object
# manufacturerNumber                  object
# reviews.date           datetime64[ns, UTC]
# reviews.doRecommend                 object
# reviews.numHelpful                 float64
# reviews.rating                       int64
# reviews.sourceURLs                  object
# reviews.text                        object
# reviews.title                       object
# reviews.username                    object
# sourceURLs                          object
# dtype: object

# %% [markdown]
# I've included a simple barplot to get a general idea of how the review ratings are distributed. It seems as there are a high number of 5 star reviews and a moderate amount of 4 star reviews indicating that people are generally satisfied with their purchase. There are a larger number of 1 star reviews than 2 star reviews.

# %%
sns.countplot(data = df,x = 'reviews.rating')
plt.title('Amazon Product Review Ratings')
# Out:
# Text(0.5, 1.0, 'Amazon Product Review Ratings')

# %% [markdown]
# We're checking out the most reviewed primary categories for products in this dataset. Most of the reviews are made in products that are electronics and after that, health and beauty. Electronics are the most popular category when it comes to Amazon shopping and reviews.

# %%
df.primaryCategories.value_counts()
# Out:
# Electronics                    13995
# Health & Beauty                12071
# Toys & Games,Electronics        1676
# Office Supplies,Electronics      386
# Electronics,Media                185
# Office Supplies                    9
# Animals & Pet Supplies             6
# Home & Garden                      2
# Electronics,Furniture              2
# Name: primaryCategories, dtype: int64

# %% [markdown]
# Now, we are looking at the most reviewed products based on their product ID and from looking at the top 5 products, it seems as batteries are the most reviewed products followed by the Kindle Fire Tablet.

# %%
df.id.value_counts()
# Out:
# AVpgNzjwLJeJML43Kpxn    8343
# AVpe7xlELJeJML43ypLz    3728
# AVqkIhxunnc1JgDc3kg_    2443
# AVqVGWQDv8e3D1O-ldFr    2370
# AVpfw2hvilAPnD_xh0rH    1676
#                         ...
# AVzoFq6UvKc47QAVe9NB       1
# AVpiZQ8r1cnluZ0-M3MN       1
# AVpe5Q3sLJeJML43xt5X       1
# AV2ElNnuvKc47QAVouhY       1
# AWK8z0pOIwln0LfXlSxH       1
# Name: id, Length: 65, dtype: int64

# %%
df.name.value_counts()
# Out:
# AmazonBasics AAA Performance Alkaline Batteries (36 Count)                               8343
# AmazonBasics AA Performance Alkaline Batteries (48 Count) - Packaging May Vary           3728
# Fire HD 8 Tablet with Alexa, 8 HD Display, 16 GB, Tangerine - with Special Offers        2443
# All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi, 16 GB - Includes Special Offers, Black    2370
# Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16 GB, Pink Kid-Proof Case                   1676
#                                                                                          ...
# Echo Dot (Previous generation)                                                              1
# AmazonBasics Single-Door Folding Metal Dog Crate - Large (42x28x30 Inches)                  1
# Two Door Top Load Pet Kennel Travel Crate Dog Cat Pet Cage Carrier Box Tray 23"             1
# Amazon Echo Show - Black                                                                    1
# AmazonBasics Nespresso Pod Storage Drawer - 50 Capsule Capacity                             1
# Name: name, Length: 65, dtype: int64

# %%
df[df['id'] == 'AVpgNzjwLJeJML43Kpxn'].head()
# Out:
#                      id                 dateAdded               dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn 2015-10-30 08:59:32+00:00 2019-04-25 09:08:16+00:00
# 1  AVpgNzjwLJeJML43Kpxn 2015-10-30 08:59:32+00:00 2019-04-25 09:08:16+00:00
# 2  AVpgNzjwLJeJML43Kpxn 2015-10-30 08:59:32+00:00 2019-04-25 09:08:16+00:00
# 3  AVpgNzjwLJeJML43Kpxn 2015-10-30 08:59:32+00:00 2019-04-25 09:08:16+00:00
# 4  AVpgNzjwLJeJML43Kpxn 2015-10-30 08:59:32+00:00 2019-04-25 09:08:16+00:00
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 4  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 3  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 4  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 1   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 2   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 3   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 4   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  ... manufacturerNumber  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...          HL-002619
# 1  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...          HL-002619
# 2  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...          HL-002619
# 3  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...          HL-002619
# 4  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...          HL-002619
#
#                reviews.date reviews.doRecommend reviews.numHelpful  \
# 0 2017-03-02 00:00:00+00:00                 NaN                NaN
# 1 2016-08-31 00:00:00+00:00                 NaN                NaN
# 2 2016-12-06 00:00:00+00:00                 NaN                NaN
# 3 2016-03-28 00:00:00+00:00                 NaN                NaN
# 4 2017-04-22 00:00:00+00:00                 NaN                NaN
#
#    reviews.rating                                 reviews.sourceURLs  \
# 0               3  https://www.amazon.com/product-reviews/B00QWO9...
# 1               4  https://www.amazon.com/product-reviews/B00QWO9...
# 2               5  https://www.amazon.com/product-reviews/B00QWO9...
# 3               5  https://www.amazon.com/product-reviews/B00QWO9...
# 4               5  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
# 2  Well they are not Duracell but for the price i...
# 3  Seem to work as well as name brand batteries a...
# 4  These batteries are very long lasting the pric...
#
#                                        reviews.title  reviews.username  \
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
# 2  ... are not Duracell but for the price i am ha...  BySharon Lambert
# 3  ... as well as name brand batteries at a much ...     Bymark sexson
# 4  ... batteries are very long lasting the price ...           Bylinda
#
#                                           sourceURLs
# 0  https://www.barcodable.com/upc/841710106442,ht...
# 1  https://www.barcodable.com/upc/841710106442,ht...
# 2  https://www.barcodable.com/upc/841710106442,ht...
# 3  https://www.barcodable.com/upc/841710106442,ht...
# 4  https://www.barcodable.com/upc/841710106442,ht...
#
# [5 rows x 21 columns]

# %%
df[df['id'] == 'AVpe7xlELJeJML43ypLz'].head()
# Out:
#                         id                 dateAdded  \
# 8358  AVpe7xlELJeJML43ypLz 2015-12-03 01:23:41+00:00
# 8359  AVpe7xlELJeJML43ypLz 2015-12-03 01:23:41+00:00
# 8360  AVpe7xlELJeJML43ypLz 2015-12-03 01:23:41+00:00
# 8361  AVpe7xlELJeJML43ypLz 2015-12-03 01:23:41+00:00
# 8362  AVpe7xlELJeJML43ypLz 2015-12-03 01:23:41+00:00
#
#                    dateUpdated  \
# 8358 2019-04-24 02:17:42+00:00
# 8359 2019-04-24 02:17:42+00:00
# 8360 2019-04-24 02:17:42+00:00
# 8361 2019-04-24 02:17:42+00:00
# 8362 2019-04-24 02:17:42+00:00
#
#                                                    name  \
# 8358  AmazonBasics AA Performance Alkaline Batteries...
# 8359  AmazonBasics AA Performance Alkaline Batteries...
# 8360  AmazonBasics AA Performance Alkaline Batteries...
# 8361  AmazonBasics AA Performance Alkaline Batteries...
# 8362  AmazonBasics AA Performance Alkaline Batteries...
#
#                                  asins         brand  \
# 8358  B00QWO9P0O,B01IB83NZG,B00MNV8E0C  Amazonbasics
# 8359  B00QWO9P0O,B01IB83NZG,B00MNV8E0C  Amazonbasics
# 8360  B00QWO9P0O,B01IB83NZG,B00MNV8E0C  Amazonbasics
# 8361  B00QWO9P0O,B01IB83NZG,B00MNV8E0C  Amazonbasics
# 8362  B00QWO9P0O,B01IB83NZG,B00MNV8E0C  Amazonbasics
#
#                                              categories primaryCategories  \
# 8358  AA,AAA,Electronics Features,Health,Electronics...   Health & Beauty
# 8359  AA,AAA,Electronics Features,Health,Electronics...   Health & Beauty
# 8360  AA,AAA,Electronics Features,Health,Electronics...   Health & Beauty
# 8361  AA,AAA,Electronics Features,Health,Electronics...   Health & Beauty
# 8362  AA,AAA,Electronics Features,Health,Electronics...   Health & Beauty
#
#                                               imageURLs  \
# 8358  https://images-na.ssl-images-amazon.com/images...
# 8359  https://images-na.ssl-images-amazon.com/images...
# 8360  https://images-na.ssl-images-amazon.com/images...
# 8361  https://images-na.ssl-images-amazon.com/images...
# 8362  https://images-na.ssl-images-amazon.com/images...
#
#                                                    keys  ...  \
# 8358  amazonbasicsaaperformancealkalinebatteries48co...  ...
# 8359  amazonbasicsaaperformancealkalinebatteries48co...  ...
# 8360  amazonbasicsaaperformancealkalinebatteries48co...  ...
# 8361  amazonbasicsaaperformancealkalinebatteries48co...  ...
# 8362  amazonbasicsaaperformancealkalinebatteries48co...  ...
#
#      manufacturerNumber              reviews.date reviews.doRecommend  \
# 8358   LR6G0748FFPAB-US 2016-08-31 00:00:00+00:00                 NaN
# 8359   LR6G0748FFPAB-US 2017-04-11 00:00:00+00:00                 NaN
# 8360   LR6G0748FFPAB-US 2017-04-17 00:00:00+00:00                 NaN
# 8361   LR6G0748FFPAB-US 2017-04-16 00:00:00+00:00                 NaN
# 8362   LR6G0748FFPAB-US 2017-04-06 00:00:00+00:00                 NaN
#
#      reviews.numHelpful  reviews.rating  \
# 8358                NaN               4
# 8359                NaN               3
# 8360                NaN               5
# 8361                NaN               5
# 8362                NaN               1
#
#                                      reviews.sourceURLs  \
# 8358  https://www.amazon.com/product-reviews/B00QWO9...
# 8359  https://www.amazon.com/product-reviews/B00QWO9...
# 8360  https://www.amazon.com/product-reviews/B00QWO9...
# 8361  https://www.amazon.com/product-reviews/B00QWO9...
# 8362  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                            reviews.text  \
# 8358  Bulk is always the less expensive way to go fo...
# 8359  Doesn't seem to last as long in some devices a...
# 8360  ive not had any problame with these batteries ...
# 8361  Well if you are looking for cheap non-recharge...
# 8362  The battery life is much poorer compared to na...
#
#                                           reviews.title   reviews.username  \
# 8358  ... always the less expensive way to go for pr...               ByMG
# 8359  ... as long in some devices as other brands bu...          ByShawn M
# 8360  ... batteries have ordered them in the past be...  ByAmazon Customer
# 8361  ... batteries that last quite a while then the...  ByLynn Pendegrass
# 8362  ... battery life is much poorer compared to na...  ByAmazon Customer
#
#                                              sourceURLs
# 8358  https://www.barcodable.com/upc/841710106411,ht...
# 8359  https://www.barcodable.com/upc/841710106411,ht...
# 8360  https://www.barcodable.com/upc/841710106411,ht...
# 8361  https://www.barcodable.com/upc/841710106411,ht...
# 8362  https://www.barcodable.com/upc/841710106411,ht...
#
# [5 rows x 21 columns]

# %%
df[df['id'] == 'AVqkIhxunnc1JgDc3kg_'].head()
# Out:
#                          id                 dateAdded  \
# 25889  AVqkIhxunnc1JgDc3kg_ 2017-03-06 14:59:43+00:00
# 25890  AVqkIhxunnc1JgDc3kg_ 2017-03-06 14:59:43+00:00
# 25891  AVqkIhxunnc1JgDc3kg_ 2017-03-06 14:59:43+00:00
# 25892  AVqkIhxunnc1JgDc3kg_ 2017-03-06 14:59:43+00:00
# 25893  AVqkIhxunnc1JgDc3kg_ 2017-03-06 14:59:43+00:00
#
#                     dateUpdated  \
# 25889 2019-02-23 02:49:38+00:00
# 25890 2019-02-23 02:49:38+00:00
# 25891 2019-02-23 02:49:38+00:00
# 25892 2019-02-23 02:49:38+00:00
# 25893 2019-02-23 02:49:38+00:00
#
#                                                     name       asins   brand  \
# 25889  Fire HD 8 Tablet with Alexa, 8 HD Display, 16 ...  B018T075DC  Amazon
# 25890  Fire HD 8 Tablet with Alexa, 8 HD Display, 16 ...  B018T075DC  Amazon
# 25891  Fire HD 8 Tablet with Alexa, 8 HD Display, 16 ...  B018T075DC  Amazon
# 25892  Fire HD 8 Tablet with Alexa, 8 HD Display, 16 ...  B018T075DC  Amazon
# 25893  Fire HD 8 Tablet with Alexa, 8 HD Display, 16 ...  B018T075DC  Amazon
#
#                                               categories primaryCategories  \
# 25889  Fire Tablets,Tablets,All Tablets,Amazon Tablet...       Electronics
# 25890  Fire Tablets,Tablets,All Tablets,Amazon Tablet...       Electronics
# 25891  Fire Tablets,Tablets,All Tablets,Amazon Tablet...       Electronics
# 25892  Fire Tablets,Tablets,All Tablets,Amazon Tablet...       Electronics
# 25893  Fire Tablets,Tablets,All Tablets,Amazon Tablet...       Electronics
#
#                                                imageURLs  \
# 25889  https://www.upccodesearch.com/images/barcode/0...
# 25890  https://www.upccodesearch.com/images/barcode/0...
# 25891  https://www.upccodesearch.com/images/barcode/0...
# 25892  https://www.upccodesearch.com/images/barcode/0...
# 25893  https://www.upccodesearch.com/images/barcode/0...
#
#                                                     keys  ...  \
# 25889  amazon/b018t075dc,firehd8tabletwithalexa8hddis...  ...
# 25890  amazon/b018t075dc,firehd8tabletwithalexa8hddis...  ...
# 25891  amazon/b018t075dc,firehd8tabletwithalexa8hddis...  ...
# 25892  amazon/b018t075dc,firehd8tabletwithalexa8hddis...  ...
# 25893  amazon/b018t075dc,firehd8tabletwithalexa8hddis...  ...
#
#       manufacturerNumber              reviews.date reviews.doRecommend  \
# 25889          53-004485 2016-12-24 00:00:00+00:00                True
# 25890          53-004485 2016-12-14 00:00:00+00:00                True
# 25891          53-004485 2017-01-18 00:00:00+00:00                True
# 25892          53-004485 2017-01-17 00:00:00+00:00                True
# 25893          53-004485 2017-03-21 00:00:00+00:00                True
#
#       reviews.numHelpful  reviews.rating  \
# 25889                0.0               5
# 25890                0.0               4
# 25891                0.0               4
# 25892                0.0               5
# 25893                0.0               5
#
#                                       reviews.sourceURLs  \
# 25889  http://reviews.bestbuy.com/3545/5620410/review...
# 25890  http://reviews.bestbuy.com/3545/5620410/review...
# 25891  http://reviews.bestbuy.com/3545/5620410/review...
# 25892  http://reviews.bestbuy.com/3545/5620410/review...
# 25893  http://reviews.bestbuy.com/3545/5620410/review...
#
#                                             reviews.text  \
# 25889  While there are some apps that are missing due...
# 25890  I bought one last year for one cousin and had ...
# 25891  I will try again for the 3rd time with my new ...
# 25892  bought this for my father, who never did much ...
# 25893  This was a request from our 7 yr old granddaug...
#
#                            reviews.title reviews.username  \
# 25889           . Nice hand sized tablet             greg
# 25890                       2nd purchase       VanStriker
# 25891              3rd time is the charm       HotTNMomma
# 25892                     5 star service       packersfan
# 25893  7 year old granddaughter loves it        Intheknow
#
#                                               sourceURLs
# 25889  http://reviews.bestbuy.com/3545/5620410/review...
# 25890  http://reviews.bestbuy.com/3545/5620410/review...
# 25891  http://reviews.bestbuy.com/3545/5620410/review...
# 25892  http://reviews.bestbuy.com/3545/5620410/review...
# 25893  http://reviews.bestbuy.com/3545/5620410/review...
#
# [5 rows x 21 columns]

# %%
df[df['id'] == 'AVqVGWQDv8e3D1O-ldFr'].head()
# Out:
#                          id                 dateAdded  \
# 13386  AVqVGWQDv8e3D1O-ldFr 2017-03-03 16:55:53+00:00
# 13388  AVqVGWQDv8e3D1O-ldFr 2017-03-03 16:55:53+00:00
# 13392  AVqVGWQDv8e3D1O-ldFr 2017-03-03 16:55:53+00:00
# 13393  AVqVGWQDv8e3D1O-ldFr 2017-03-03 16:55:53+00:00
# 13394  AVqVGWQDv8e3D1O-ldFr 2017-03-03 16:55:53+00:00
#
#                     dateUpdated  \
# 13386 2019-03-09 07:13:43+00:00
# 13388 2019-03-09 07:13:43+00:00
# 13392 2019-03-09 07:13:43+00:00
# 13393 2019-03-09 07:13:43+00:00
# 13394 2019-03-09 07:13:43+00:00
#
#                                                     name  \
# 13386  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 13388  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 13392  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 13393  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 13394  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#                        asins   brand  \
# 13386  B018SZT3BK,B01AHB9CN2  Amazon
# 13388  B018SZT3BK,B01AHB9CN2  Amazon
# 13392  B018SZT3BK,B01AHB9CN2  Amazon
# 13393  B018SZT3BK,B01AHB9CN2  Amazon
# 13394  B018SZT3BK,B01AHB9CN2  Amazon
#
#                                               categories primaryCategories  \
# 13386  Fire Tablets,Computers/Tablets & Networking,El...       Electronics
# 13388  Fire Tablets,Computers/Tablets & Networking,El...       Electronics
# 13392  Fire Tablets,Computers/Tablets & Networking,El...       Electronics
# 13393  Fire Tablets,Computers/Tablets & Networking,El...       Electronics
# 13394  Fire Tablets,Computers/Tablets & Networking,El...       Electronics
#
#                                                imageURLs  \
# 13386  http://i.ebayimg.com/thumbs/images/g/9DAAAOSwE...
# 13388  http://i.ebayimg.com/thumbs/images/g/9DAAAOSwE...
# 13392  http://i.ebayimg.com/thumbs/images/g/9DAAAOSwE...
# 13393  http://i.ebayimg.com/thumbs/images/g/9DAAAOSwE...
# 13394  http://i.ebayimg.com/thumbs/images/g/9DAAAOSwE...
#
#                                                     keys  ...  \
# 13386  amazonfirehd88intablet16gbblackb018szt3bk6thge...  ...
# 13388  amazonfirehd88intablet16gbblackb018szt3bk6thge...  ...
# 13392  amazonfirehd88intablet16gbblackb018szt3bk6thge...  ...
# 13393  amazonfirehd88intablet16gbblackb018szt3bk6thge...  ...
# 13394  amazonfirehd88intablet16gbblackb018szt3bk6thge...  ...
#
#       manufacturerNumber              reviews.date reviews.doRecommend  \
# 13386          53-004484 2016-12-24 00:00:00+00:00                True
# 13388          53-004484 2016-12-14 00:00:00+00:00                True
# 13392          53-004484 2017-01-18 00:00:00+00:00                True
# 13393          53-004484 2017-01-17 00:00:00+00:00                True
# 13394          53-004484 2017-03-21 00:00:00+00:00                True
#
#       reviews.numHelpful  reviews.rating  \
# 13386                0.0               5
# 13388                0.0               4
# 13392                0.0               4
# 13393                0.0               5
# 13394                0.0               5
#
#                                       reviews.sourceURLs  \
# 13386  http://reviews.bestbuy.com/3545/5620406/review...
# 13388  http://reviews.bestbuy.com/3545/5538501/review...
# 13392  http://reviews.bestbuy.com/3545/5538501/review...
# 13393  http://reviews.bestbuy.com/3545/5538501/review...
# 13394  http://reviews.bestbuy.com/3545/5620406/review...
#
#                                             reviews.text  \
# 13386  While there are some apps that are missing due...
# 13388  I bought one last year for one cousin and had ...
# 13392  I will try again for the 3rd time with my new ...
# 13393  bought this for my father, who never did much ...
# 13394  This was a request from our 7 yr old granddaug...
#
#                            reviews.title reviews.username  \
# 13386           . Nice hand sized tablet             greg
# 13388                       2nd purchase       VanStriker
# 13392              3rd time is the charm       HotTNMomma
# 13393                     5 star service       packersfan
# 13394  7 year old granddaughter loves it        Intheknow
#
#                                               sourceURLs
# 13386  http://reviews.bestbuy.com/3545/5620406/review...
# 13388  http://reviews.bestbuy.com/3545/5620406/review...
# 13392  http://reviews.bestbuy.com/3545/5620406/review...
# 13393  http://reviews.bestbuy.com/3545/5620406/review...
# 13394  http://reviews.bestbuy.com/3545/5620406/review...
#
# [5 rows x 21 columns]

# %%
df[df['id'] == 'AVpfw2hvilAPnD_xh0rH'].head()
# Out:
#                          id                 dateAdded  \
# 13387  AVpfw2hvilAPnD_xh0rH 2017-01-11 06:58:33+00:00
# 13389  AVpfw2hvilAPnD_xh0rH 2017-01-11 06:58:33+00:00
# 13390  AVpfw2hvilAPnD_xh0rH 2017-01-11 06:58:33+00:00
# 13391  AVpfw2hvilAPnD_xh0rH 2017-01-11 06:58:33+00:00
# 13396  AVpfw2hvilAPnD_xh0rH 2017-01-11 06:58:33+00:00
#
#                     dateUpdated  \
# 13387 2019-03-09 07:13:43+00:00
# 13389 2019-03-09 07:13:43+00:00
# 13390 2019-03-09 07:13:43+00:00
# 13391 2019-03-09 07:13:43+00:00
# 13396 2019-03-09 07:13:43+00:00
#
#                                                     name       asins   brand  \
# 13387  Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...  B018Y226XO  Amazon
# 13389  Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...  B018Y226XO  Amazon
# 13390  Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...  B018Y226XO  Amazon
# 13391  Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...  B018Y226XO  Amazon
# 13396  Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...  B018Y226XO  Amazon
#
#                                               categories  \
# 13387  Fire Tablets,Learning Toys,Toys,Tablets,Amazon...
# 13389  Fire Tablets,Learning Toys,Toys,Tablets,Amazon...
# 13390  Fire Tablets,Learning Toys,Toys,Tablets,Amazon...
# 13391  Fire Tablets,Learning Toys,Toys,Tablets,Amazon...
# 13396  Fire Tablets,Learning Toys,Toys,Tablets,Amazon...
#
#               primaryCategories  \
# 13387  Toys & Games,Electronics
# 13389  Toys & Games,Electronics
# 13390  Toys & Games,Electronics
# 13391  Toys & Games,Electronics
# 13396  Toys & Games,Electronics
#
#                                                imageURLs  \
# 13387  https://pisces.bbystatic.com/image2/BestBuy_US...
# 13389  https://pisces.bbystatic.com/image2/BestBuy_US...
# 13390  https://pisces.bbystatic.com/image2/BestBuy_US...
# 13391  https://pisces.bbystatic.com/image2/BestBuy_US...
# 13396  https://pisces.bbystatic.com/image2/BestBuy_US...
#
#                                                     keys  ...  \
# 13387  amazon/53004754,841667103372,0841667103372,7in...  ...
# 13389  amazon/53004754,841667103372,0841667103372,7in...  ...
# 13390  amazon/53004754,841667103372,0841667103372,7in...  ...
# 13391  amazon/53004754,841667103372,0841667103372,7in...  ...
# 13396  amazon/53004754,841667103372,0841667103372,7in...  ...
#
#       manufacturerNumber              reviews.date reviews.doRecommend  \
# 13387          53-004754 2017-03-04 00:00:00+00:00                True
# 13389          53-004754 2016-12-16 00:00:00+00:00                True
# 13390          53-004754 2017-01-07 00:00:00+00:00                True
# 13391          53-004754 2017-03-15 00:00:00+00:00                True
# 13396          53-004754 2016-12-26 00:00:00+00:00                True
#
#       reviews.numHelpful  reviews.rating  \
# 13387                0.0               5
# 13389                0.0               4
# 13390                0.0               5
# 13391                0.0               4
# 13396                0.0               5
#
#                                       reviews.sourceURLs  \
# 13387  http://reviews.bestbuy.com/3545/5026100/review...
# 13389  http://reviews.bestbuy.com/3545/5026100/review...
# 13390  http://reviews.bestbuy.com/3545/5026100/review...
# 13391  http://reviews.bestbuy.com/3545/5026100/review...
# 13396  http://reviews.bestbuy.com/3545/5026100/review...
#
#                                             reviews.text  \
# 13387  great tablet for kids when traveling. my grand...
# 13389  Bought this for my 2 yr old daughter. She was ...
# 13390  Kindle products are fantastic. I've used a kin...
# 13391  Best buy ever for my 3 year old. Only purchase...
# 13396  My little girl loves her Kindle. I'm so happy ...
#
#                                            reviews.title reviews.username  \
# 13387                                2 year old loves it            betty
# 13389                                   2yr old approved             Mike
# 13390  3 year old granddaughter loves it!!! Easy for her           Jeanie
# 13391                                3 year old's Heaven         kidslove
# 13396                                   9 year old loves          Yve0904
#
#                                               sourceURLs
# 13387  http://www.toysrus.com/product/index.jsp?produ...
# 13389  http://www.toysrus.com/product/index.jsp?produ...
# 13390  http://www.toysrus.com/product/index.jsp?produ...
# 13391  http://www.toysrus.com/product/index.jsp?produ...
# 13396  http://www.toysrus.com/product/index.jsp?produ...
#
# [5 rows x 21 columns]

# %% [markdown]
# We're examining the mean ratings of products in each department and it seems that electronics have a generally higher rating than health and beauty products. It would seem so because electronics are more reliable and functional than health and beauty products and people would rate electronics based only their functionality where as there are a lot of aspects of quality when it comes to health and beauty products as well as office supplies and toys and games.

# %%
df.groupby(['primaryCategories']).mean()['reviews.rating']
# Out:
# primaryCategories
# Animals & Pet Supplies         4.500000
# Electronics                    4.563987
# Electronics,Furniture          5.000000
# Electronics,Media              4.664865
# Health & Beauty                4.449756
# Home & Garden                  4.500000
# Office Supplies                5.000000
# Office Supplies,Electronics    4.554404
# Toys & Games,Electronics       4.531026
# Name: reviews.rating, dtype: float64

# %% [markdown]
# It is important to examine the number of entries in the 'Electronics,Furniture' category as it has a perfect 5 mean rating. Same goes with 'Office Supplies'.

# %%
df[df['primaryCategories']== 'Electronics,Furniture']
# Out:
#                          id                 dateAdded  \
# 13380  AWMjN1SSIwln0LfXmWs7 2018-05-02 14:06:20+00:00
# 13384  AWMjN1SSIwln0LfXmWs7 2018-05-02 14:06:20+00:00
#
#                     dateUpdated  \
# 13380 2019-03-09 07:13:48+00:00
# 13384 2019-03-09 07:13:48+00:00
#
#                                                     name       asins   brand  \
# 13380  All-new Echo (2nd Generation) with improved so...  B0752151W6  Amazon
# 13384  All-new Echo (2nd Generation) with improved so...  B0752151W6  Amazon
#
#                                               categories  \
# 13380  Amazon Echo,Smart Speakers,Electronics,Digital...
# 13384  Amazon Echo,Smart Speakers,Electronics,Digital...
#
#            primaryCategories  \
# 13380  Electronics,Furniture
# 13384  Electronics,Furniture
#
#                                                imageURLs  \
# 13380  https://i.ebayimg.com/thumbs/images/g/tOMAAOSw...
# 13384  https://i.ebayimg.com/thumbs/images/g/tOMAAOSw...
#
#                                                     keys  ...  \
# 13380  allnewecho2ndgenerationwithimprovedsoundpowere...  ...
# 13384  allnewecho2ndgenerationwithimprovedsoundpowere...  ...
#
#       manufacturerNumber              reviews.date reviews.doRecommend  \
# 13380          53-007169 2018-01-17 00:00:00+00:00                True
# 13384          53-007169 2018-03-21 00:00:00+00:00                True
#
#       reviews.numHelpful  reviews.rating  \
# 13380                0.0               5
# 13384                0.0               5
#
#                                       reviews.sourceURLs  \
# 13380  https://reviews.bestbuy.com/3545/6130002/revie...
# 13384  https://reviews.bestbuy.com/3545/6130002/revie...
#
#                                             reviews.text  \
# 13380  After researching The Amazon Echo and the Goog...
# 13384  I like using Amazon Echo for playing calming m...
#
#                          reviews.title reviews.username  \
# 13380  Great speaker and user friendly          Ladybug
# 13384                     Smart Device    raquelladonna
#
#                                               sourceURLs
# 13380  https://www.newegg.com/Product/Product.aspx%25...
# 13384  https://www.newegg.com/Product/Product.aspx%25...
#
# [2 rows x 21 columns]

# %%
df[df['primaryCategories']== 'Office Supplies']
# Out:
#                          id                 dateAdded  \
# 12156  AVpfhcniLJeJML43-t4G 2015-10-30 10:58:06+00:00
# 12157  AVpfhcniLJeJML43-t4G 2015-10-30 10:58:06+00:00
# 12158  AVpfhcniLJeJML43-t4G 2015-10-30 10:58:06+00:00
# 12159  AVpfhcniLJeJML43-t4G 2015-10-30 10:58:06+00:00
# 12160  AVpfhcniLJeJML43-t4G 2015-10-30 10:58:06+00:00
# 12161  AVpfhcniLJeJML43-t4G 2015-10-30 10:58:06+00:00
# 12162  AVpfhcniLJeJML43-t4G 2015-10-30 10:58:06+00:00
# 12163  AVpfhcniLJeJML43-t4G 2015-10-30 10:58:06+00:00
# 12164  AVpfhcniLJeJML43-t4G 2015-10-30 10:58:06+00:00
#
#                     dateUpdated  \
# 12156 2019-04-22 10:21:26+00:00
# 12157 2019-04-22 10:21:26+00:00
# 12158 2019-04-22 10:21:26+00:00
# 12159 2019-04-22 10:21:26+00:00
# 12160 2019-04-22 10:21:26+00:00
# 12161 2019-04-22 10:21:26+00:00
# 12162 2019-04-22 10:21:26+00:00
# 12163 2019-04-22 10:21:26+00:00
# 12164 2019-04-22 10:21:26+00:00
#
#                                                     name  \
# 12156  Expanding Accordion File Folder Plastic Portab...
# 12157  Expanding Accordion File Folder Plastic Portab...
# 12158  Expanding Accordion File Folder Plastic Portab...
# 12159  Expanding Accordion File Folder Plastic Portab...
# 12160  Expanding Accordion File Folder Plastic Portab...
# 12161  Expanding Accordion File Folder Plastic Portab...
# 12162  Expanding Accordion File Folder Plastic Portab...
# 12163  Expanding Accordion File Folder Plastic Portab...
# 12164  Expanding Accordion File Folder Plastic Portab...
#
#                                   asins         brand  \
# 12156  B0002LCUZK,B010CEC6MI,B01B25NN64  Amazonbasics
# 12157  B0002LCUZK,B010CEC6MI,B01B25NN64  Amazonbasics
# 12158  B0002LCUZK,B010CEC6MI,B01B25NN64  Amazonbasics
# 12159  B0002LCUZK,B010CEC6MI,B01B25NN64  Amazonbasics
# 12160  B0002LCUZK,B010CEC6MI,B01B25NN64  Amazonbasics
# 12161  B0002LCUZK,B010CEC6MI,B01B25NN64  Amazonbasics
# 12162  B0002LCUZK,B010CEC6MI,B01B25NN64  Amazonbasics
# 12163  B0002LCUZK,B010CEC6MI,B01B25NN64  Amazonbasics
# 12164  B0002LCUZK,B010CEC6MI,B01B25NN64  Amazonbasics
#
#                                               categories primaryCategories  \
# 12156  Office,File Jackets & File Pockets,File Folder...   Office Supplies
# 12157  Office,File Jackets & File Pockets,File Folder...   Office Supplies
# 12158  Office,File Jackets & File Pockets,File Folder...   Office Supplies
# 12159  Office,File Jackets & File Pockets,File Folder...   Office Supplies
# 12160  Office,File Jackets & File Pockets,File Folder...   Office Supplies
# 12161  Office,File Jackets & File Pockets,File Folder...   Office Supplies
# 12162  Office,File Jackets & File Pockets,File Folder...   Office Supplies
# 12163  Office,File Jackets & File Pockets,File Folder...   Office Supplies
# 12164  Office,File Jackets & File Pockets,File Folder...   Office Supplies
#
#                                                imageURLs  \
# 12156  https://i.ebayimg.com/images/g/qAwAAOSwptJab16...
# 12157  https://i.ebayimg.com/images/g/qAwAAOSwptJab16...
# 12158  https://i.ebayimg.com/images/g/qAwAAOSwptJab16...
# 12159  https://i.ebayimg.com/images/g/qAwAAOSwptJab16...
# 12160  https://i.ebayimg.com/images/g/qAwAAOSwptJab16...
# 12161  https://i.ebayimg.com/images/g/qAwAAOSwptJab16...
# 12162  https://i.ebayimg.com/images/g/qAwAAOSwptJab16...
# 12163  https://i.ebayimg.com/images/g/qAwAAOSwptJab16...
# 12164  https://i.ebayimg.com/images/g/qAwAAOSwptJab16...
#
#                                                     keys  ...  \
# 12156  expandingaccordionfilefolderplasticportabledoc...  ...
# 12157  expandingaccordionfilefolderplasticportabledoc...  ...
# 12158  expandingaccordionfilefolderplasticportabledoc...  ...
# 12159  expandingaccordionfilefolderplasticportabledoc...  ...
# 12160  expandingaccordionfilefolderplasticportabledoc...  ...
# 12161  expandingaccordionfilefolderplasticportabledoc...  ...
# 12162  expandingaccordionfilefolderplasticportabledoc...  ...
# 12163  expandingaccordionfilefolderplasticportabledoc...  ...
# 12164  expandingaccordionfilefolderplasticportabledoc...  ...
#
#       manufacturerNumber              reviews.date reviews.doRecommend  \
# 12156           PBH-2557 2017-03-02 00:00:00+00:00                 NaN
# 12157           PBH-2557 2019-03-25 00:00:00+00:00                 NaN
# 12158           PBH-2557 2017-11-09 00:00:00+00:00                 NaN
# 12159           PBH-2557 2017-03-27 00:00:00+00:00                 NaN
# 12160           PBH-2557 2017-01-12 00:00:00+00:00                 NaN
# 12161           PBH-2557 2018-06-12 00:00:00+00:00                 NaN
# 12162           PBH-2557 2017-08-16 00:00:00+00:00                 NaN
# 12163           PBH-2557 2017-04-26 00:00:00+00:00                 NaN
# 12164           PBH-2557 2018-05-12 00:00:00+00:00                 NaN
#
#       reviews.numHelpful  reviews.rating  \
# 12156                NaN               5
# 12157                NaN               5
# 12158                NaN               5
# 12159                NaN               5
# 12160                NaN               5
# 12161                NaN               5
# 12162                NaN               5
# 12163                NaN               5
# 12164                NaN               5
#
#                                       reviews.sourceURLs  \
# 12156  http://www.ebay.com/itm/File-Pocket-Expanding-...
# 12157  https://www.ebay.com/itm/Expanding-Accordion-F...
# 12158  https://www.ebay.com/itm/Expanding-File-Tabs-F...
# 12159  http://www.ebay.com/itm/File-Pocket-Expanding-...
# 12160  http://www.ebay.com/itm/File-Pocket-Expanding-...
# 12161  https://www.ebay.com/urw/product-reviews/10014...
# 12162  https://www.ebay.com/urw/product-reviews/17747...
# 12163  https://www.ebay.com/itm/Expanding-File-Tabs-F...
# 12164  https://www.ebay.com/itm/Expanding-Accordion-F...
#
#                                             reviews.text  \
# 12156  This folder also expands on the bottom. Will a...
# 12157                             Exactly what I needed.
# 12158  Nice product. Will work perfectly for my proje...
# 12159       A useful folder organizer with good quality.
# 12160  I love the portability of this expandable file...
# 12161                          Exactly what I needed!!!!
# 12162  Good product cheap price! Very happy with my p...
# 12163                  A very good document storage grat
# 12164                        Very sturdy and functional.
#
#                 reviews.title  reviews.username  \
# 12156  Bottom expands as well  happypersonohyeh
# 12157                  Folder        99kurama99
# 12158                  Folder          juleekae
# 12159           Good purchase           ml2shop
# 12160  Great product and cost        connieinla
# 12161                Perfect!          lobo5981
# 12162      Satisfied customer    j-stjin-sdm3ip
# 12163  The one i need perfect    truck-electric
# 12164               WELL-MADE        kiss_rocks
#
#                                               sourceURLs
# 12156  http://www.ebay.com/itm/Expanding-File-Tabs-Fo...
# 12157  http://www.ebay.com/itm/Expanding-File-Tabs-Fo...
# 12158  http://www.ebay.com/itm/Expanding-File-Tabs-Fo...
# 12159  http://www.ebay.com/itm/Expanding-File-Tabs-Fo...
# 12160  http://www.ebay.com/itm/Expanding-File-Tabs-Fo...
# 12161  http://www.ebay.com/itm/Expanding-File-Tabs-Fo...
# 12162  http://www.ebay.com/itm/Expanding-File-Tabs-Fo...
# 12163  http://www.ebay.com/itm/Expanding-File-Tabs-Fo...
# 12164  http://www.ebay.com/itm/Expanding-File-Tabs-Fo...
#
# [9 rows x 21 columns]

# %% [markdown]
# Now we are seeing how the length of the review text correlates with the review rating (out of 5 stars).

# %%
df['lengthofreview'] = [len(i) for i in df['reviews.text']]

# %%
sns.scatterplot(x = 'reviews.rating', y = 'lengthofreview', data = df)

# %% [markdown]
# Generally longer text reviews correlates to higher ratings judging off of the scatterplot. There are large outliers for 4 star ratings and it is important to investigate those outliers.

# %% [markdown]
# We are going to investigate the correlation between difference between the date of the product being added to the database and the date the product review was posted with the overall rating that the user gave the product.

# %%
df['reviewsminusdateadd'] = df['reviews.date'] - df['dateAdded']
days = df['reviewsminusdateadd'].astype('timedelta64[D]')

# %%
sns.scatterplot(df['reviews.rating'],days)

# %% [markdown]
# If there is a higher difference between the date the product was added to the database and the date the review was posted, the review will generally yield a greater rating as can be seen from the plot. This can be attributed to the reliability of the product. The 'reviewsminusdateadd' column gives a rough idea of how long a product has been on the market and available for sale and products with longer lifespans on the market correlates to higher reviews given by users.

# %% [markdown]
# The next step is to get to the primary objective of the project: to be able to predict review ratings based on the text of the reviews. It is important to examine the most common phrases and bigrams of all the review text data. In order to do this, we need to implement a trigram vectorizer.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Instantiate a trigram vectorizer
cv_trigram_vec = CountVectorizer(max_features=200, 
                                 stop_words='english', 
                                 ngram_range = (1,2))

# Fit and apply trigram vectorizer
cv_trigram = cv_trigram_vec.fit_transform(df['reviews.text'])

# Print the trigram features
print(cv_trigram_vec.get_feature_names())
# Out:
# ['aa', 'aaa', 'able', 'access', 'alexa', 'amazing', 'amazon', 'app', 'apps', 'available', 'awesome', 'basic', 'batteries', 'batteries work', 'battery', 'battery life', 'beat', 'best', 'best buy', 'better', 'big', 'book', 'books', 'bought', 'box', 'brand', 'brand batteries', 'brands', 'buy', 'buying', 'came', 'camera', 'case', 'charge', 'cheap', 'cheaper', 'child', 'children', 'christmas', 'come', 'comes', 'controls', 'cost', 'daughter', 'day', 'deal', 'definitely', 'device', 'devices', 'did', 'didn', 'different', 'does', 'doesn', 'don', 'download', 'durable', 'duracell', 'easy', 'easy use', 'energizer', 'enjoy', 'excellent', 'expected', 'expensive', 'far', 'fast', 'features', 'fine', 'free', 'friendly', 'games', 'getting', 'gift', 'going', 'good', 'good batteries', 'good price', 'google', 'got', 'granddaughter', 'grandson', 'great', 'great batteries', 'great deal', 'great price', 'great product', 'great tablet', 'great value', 'happy', 'haven', 'having', 'hd', 'highly', 'hold', 'hours', 'internet', 'ipad', 'issues', 'item', 'just', 'kid', 'kids', 'kindle', 'know', 'lasting', 'learning', 'life', 'light', 'like', 'little', 'll', 'long', 'longer', 'looking', 'lot', 'lots', 'love', 'loved', 'loves', 'low', 'make', 'makes', 'money', 'months', 'movies', 'music', 'need', 'needed', 'needs', 'new', 'nice', 'old', 'ones', 'overall', 'pack', 'parental', 'perfect', 'performance', 'play', 'play games', 'playing', 'power', 'pretty', 'price', 'prime', 'product', 'products', 'purchase', 'purchased', 'quality', 'quickly', 'read', 'reader', 'reading', 'really', 'recommend', 'replace', 'right', 'say', 'screen', 'set', 'size', 'small', 'son', 'sound', 'storage', 'store', 'sure', 'tablet', 'tablets', 'thing', 'things', 'think', 'time', 'times', 'toys', 'use', 'used', 'user', 'uses', 'using', 'value', 've', 'videos', 'want', 'wanted', 'watch', 'way', 'wife', 'work', 'work great', 'worked', 'working', 'works', 'works great', 'worth', 'year', 'year old', 'years']

# %%
cv_tri_df = pd.DataFrame(cv_trigram.toarray(), 
                 columns=cv_trigram_vec.get_feature_names()).add_prefix('Counts_')

# Print the top 5 words in the sorted output
print(cv_tri_df.sum().sort_values(ascending=False).head())
# Out:
# Counts_great        9464
# Counts_batteries    8145
# Counts_tablet       6685
# Counts_good         5906
# Counts_price        5221
# dtype: int64

# %%
df['reviews.rating'].dtype
# Out:
# dtype('int64')

# %%
df['reviews.rating'].value_counts()
# Out:
# 5    19897
# 4     5648
# 3     1206
# 1      965
# 2      616
# Name: reviews.rating, dtype: int64

# %% [markdown]
# In this step, I'm rearranging and creating new categories from the review ratings. This is because it is hard to distinguish reviews say if they were 1 star apart even for a human. I have decided to categorize 4 or 5 star reviews into 'High', 3 stars into 'Medium', 1 or 2 stars into 'Low'.

# %%
df['reviews.label'] = 'High'
df.loc[df['reviews.rating'] == 3, 'reviews.label'] = 'Medium'
df.loc[df['reviews.rating'] == 2, 'reviews.label'] = 'Low'
df.loc[df['reviews.rating'] == 1, 'reviews.label'] = 'Low'

# %%
df['reviews.label'].value_counts()
# Out:
# High      25545
# Low        1581
# Medium     1206
# Name: reviews.label, dtype: int64

# %% [markdown]
# There is an abundance of 5 star ratings, so I decided to approach this imbalance by downsampling the 'High' reviews to approximately double of the other categories.

# %%
from sklearn.utils import resample


X = pd.concat([df['reviews.text'],df['reviews.label']], axis = 1)

rating3 = X[X['reviews.label'] == 'High']
rating2 = X[X['reviews.label'] == 'Medium']
rating1 = X[X['reviews.label'] == 'Low']
rating3_downsample = resample(rating3,
                          replace=True, 
                          n_samples=2* len(rating2), 
                          random_state=0)

downsampled = pd.concat([rating3_downsample,rating2,rating1])
y = downsampled['reviews.label']
X = downsampled.drop('reviews.label', axis = 1)
X
# Out:
#                                             reviews.text
# 2990                                                Nice
# 12512  Sleep design and works great. Ideal gift for t...
# 11193                                    These are great
# 22007  I like this Kindle the only this is it does no...
# 14990  I enjoy it a lot for my son yeah I really enjo...
# ...                                                  ...
# 28254  Freeze frequently... No way to trouble shoot o...
# 28265  was cheap, can not run chrome stuff, returned ...
# 28268  Didn't have some of the features I was looking...
# 28269  My Hulu plays perfectly..great volume. Kindle ...
# 28285  Worked great but after awhile I wouldn't unloc...
#
# [5199 rows x 1 columns]

# %% [markdown]
# Wordclouds for each of the categories of ratings

# %%
from wordcloud import WordCloud, STOPWORDS
text = " ".join(review for review in rating3['reviews.text'])
stopwords = set(STOPWORDS)
stopwords.update(['tablet','batteries','Kindle'])
wordcloud = WordCloud(stopwords = stopwords,background_color="white").generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text = " ".join(review for review in rating2['reviews.text'])
stopwords = set(STOPWORDS)
stopwords.update(['tablet','batteries','Kindle'])
wordcloud = WordCloud(stopwords = stopwords,background_color="white").generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text = " ".join(review for review in rating1['reviews.text'])
stopwords = set(STOPWORDS)
stopwords.update(['tablet','batteries','Kindle','Amazon'])
wordcloud = WordCloud(stopwords = stopwords,background_color="white").generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
y.value_counts()
# Out:
# High      2412
# Low       1581
# Medium    1206
# Name: reviews.label, dtype: int64

# %% [markdown]
# I am preparing the text data for vectorization and TFIDF transformation and then performing a train test split with a split of 20% on the traning data. Then I am going to run through several algorithms of choice and graphing a box plot of the best f1 scores to see which algorithms performed best on f1 score. I decided to go with f1 score because it is a better metric of model evaluation for unbalanced data as our data is still somewhat imbalanced.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0, test_size = 0.2)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train['reviews.text'])
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
import xgboost as xgb
plt.figure(figsize = (12,5))
from sklearn.model_selection import cross_val_score
models = [
    RandomForestClassifier(max_depth=3, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
    xgb.XGBClassifier(objective='multi:softmax',num_class = 3, random_state =0, eval_metric = 'mlogloss')
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  f1micros = cross_val_score(model, X_train_tfidf, y_train, scoring='f1_micro', cv=CV)
  for fold_idx, f1micro in enumerate(f1micros):
    entries.append((model_name, fold_idx, f1micro))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'f1_micro'])
import seaborn as sns
sns.boxplot(x='model_name', y='f1_micro', data=cv_df)
sns.stripplot(x='model_name', y='f1_micro', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()

# %% [markdown]
# It seems as if Linear SVC performed the best in micro f1 score. Micro f1 score takes into consideration of unbalanced classes and adds weights to each of the classes. Linear SVC seems to have performed the best but however there is a lot more complexity and learning in XGBoost and it has proved to be the more reliable algorithm. It has mostly been the algorithm of choice for competition winning models on Kaggle. I decided to tune XGBoost parameters to see if I could get a better result than LinearSVC.

# %%
cv_df.groupby('model_name').f1_micro.mean()
# Out:
# model_name
# LinearSVC                 0.791776
# LogisticRegression        0.771094
# MultinomialNB             0.693195
# RandomForestClassifier    0.496273
# XGBClassifier             0.786484
# Name: f1_micro, dtype: float64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(sublinear_tf=True, norm='l2',min_df = 2, encoding='latin-1', ngram_range=(1, 2), stop_words='english', token_pattern=r'\b[^\d\W]+\b')

features = tfidf.fit_transform(X['reviews.text']).toarray()
labels = y
features.shape
# Out:
# (5199, 15413)

# %%
model = LinearSVC()
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test, y_pred)
print(conf_mat)
# Out:
# [[701  37  51]
#  [ 39 460  47]
#  [ 89  68 224]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.85      0.89      0.87       789
#          Low       0.81      0.84      0.83       546
#       Medium       0.70      0.59      0.64       381
#
#     accuracy                           0.81      1716
#    macro avg       0.79      0.77      0.78      1716
# weighted avg       0.80      0.81      0.80      1716

# %%
import xgboost as xgb
xgbmodel = xgb.XGBClassifier(objective='multi:softmax',num_class = 3, random_state =0, eval_metric = 'mlogloss')
xgbmodel.fit(X_train,y_train)
xgb_pred = xgbmodel.predict(X_test)
conf_mat2 = confusion_matrix(y_test, xgb_pred)
print(conf_mat2)
# Out:
# [[694  40  55]
#  [ 63 437  46]
#  [ 87  71 223]]

# %%
from xgboost import plot_importance

plot_importance(xgbmodel, max_num_features=20 )
plt.show()

# %%
tfidf.get_feature_names()[901]
# Out:
# 'batteries'

# %%
print(classification_report(y_test, xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.82      0.88      0.85       789
#          Low       0.80      0.80      0.80       546
#       Medium       0.69      0.59      0.63       381
#
#     accuracy                           0.79      1716
#    macro avg       0.77      0.76      0.76      1716
# weighted avg       0.78      0.79      0.79      1716

# %% [markdown]
# Conducting a random search on the XGBoost Classifier

# %%
import time

import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
clf = xgb.XGBClassifier(objective='multi:softmax',num_class = 3, random_state =0, eval_metric = 'mlogloss')


param_grid = {
        'max_depth': [6, 10, 15, 20],
        'learning_rate': [0.001, 0.01, 0.1, 0.2, 0.3],
        'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bytree': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bylevel': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'min_child_weight': [0.5, 1.0, 3.0, 5.0, 7.0, 10.0],
        'gamma': [0, 0.25, 0.5, 1.0],
        'reg_lambda': [0.1, 1.0, 5.0, 10.0, 50.0, 100.0],
        'n_estimators': [50,100,150]}



rs_clf = RandomizedSearchCV(clf, param_grid, n_iter=20,
                            n_jobs=1, verbose=2, cv=2,
                            scoring='roc_auc_ovr_weighted', refit=False, random_state=42)
print("Randomized search..")
search_time_start = time.time()
rs_clf.fit(X_train, y_train)
print("Randomized search time:", time.time() - search_time_start)

best_score = rs_clf.best_score_
best_params = rs_clf.best_params_
print("Best score: {}".format(best_score))
print("Best params: ")
for param_name in sorted(best_params.keys()):
    print('%s: %r' % (param_name, best_params[param_name]))
# Out:
# Randomized search..
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# [CV] subsample=0.9, reg_lambda=100.0, n_estimators=50, min_child_weight=5.0, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=1.0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  subsample=0.9, reg_lambda=100.0, n_estimators=50, min_child_weight=5.0, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=1.0, total=  12.6s
# [CV] subsample=0.9, reg_lambda=100.0, n_estimators=50, min_child_weight=5.0, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=1.0
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   12.5s remaining:    0.0s
# [CV]  subsample=0.9, reg_lambda=100.0, n_estimators=50, min_child_weight=5.0, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=1.0, total=  12.6s
# [CV] subsample=0.5, reg_lambda=0.1, n_estimators=150, min_child_weight=10.0, max_depth=20, learning_rate=0.3, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=1.0
# [CV]  subsample=0.5, reg_lambda=0.1, n_estimators=150, min_child_weight=10.0, max_depth=20, learning_rate=0.3, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=1.0, total=  42.9s
# [CV] subsample=0.5, reg_lambda=0.1, n_estimators=150, min_child_weight=10.0, max_depth=20, learning_rate=0.3, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=1.0
# [CV]  subsample=0.5, reg_lambda=0.1, n_estimators=150, min_child_weight=10.0, max_depth=20, learning_rate=0.3, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=1.0, total=  53.6s
# [CV] subsample=0.9, reg_lambda=10.0, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.3, gamma=0.25, colsample_bytree=0.7, colsample_bylevel=1.0
# [CV]  subsample=0.9, reg_lambda=10.0, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.3, gamma=0.25, colsample_bytree=0.7, colsample_bylevel=1.0, total= 1.0min
# [CV] subsample=0.9, reg_lambda=10.0, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.3, gamma=0.25, colsample_bytree=0.7, colsample_bylevel=1.0
# [CV]  subsample=0.9, reg_lambda=10.0, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.3, gamma=0.25, colsample_bytree=0.7, colsample_bylevel=1.0, total=  58.3s
# [CV] subsample=1.0, reg_lambda=10.0, n_estimators=100, min_child_weight=1.0, max_depth=6, learning_rate=0.2, gamma=0.5, colsample_bytree=0.8, colsample_bylevel=0.8
# [CV]  subsample=1.0, reg_lambda=10.0, n_estimators=100, min_child_weight=1.0, max_depth=6, learning_rate=0.2, gamma=0.5, colsample_bytree=0.8, colsample_bylevel=0.8, total=  38.7s
# [CV] subsample=1.0, reg_lambda=10.0, n_estimators=100, min_child_weight=1.0, max_depth=6, learning_rate=0.2, gamma=0.5, colsample_bytree=0.8, colsample_bylevel=0.8
# [CV]  subsample=1.0, reg_lambda=10.0, n_estimators=100, min_child_weight=1.0, max_depth=6, learning_rate=0.2, gamma=0.5, colsample_bytree=0.8, colsample_bylevel=0.8, total=  43.4s
# [CV] subsample=0.5, reg_lambda=0.1, n_estimators=50, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=0.6, colsample_bylevel=0.4
# [CV]  subsample=0.5, reg_lambda=0.1, n_estimators=50, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=0.6, colsample_bylevel=0.4, total=  17.6s
# [CV] subsample=0.5, reg_lambda=0.1, n_estimators=50, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=0.6, colsample_bylevel=0.4
# [CV]  subsample=0.5, reg_lambda=0.1, n_estimators=50, min_child_weight=1.0, max_depth=15, learning_rate=0.1, gamma=0, colsample_bytree=0.6, colsample_bylevel=0.4, total=  17.7s
# [CV] subsample=0.5, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=10, learning_rate=0.1, gamma=0, colsample_bytree=0.4, colsample_bylevel=0.6
# [CV]  subsample=0.5, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=10, learning_rate=0.1, gamma=0, colsample_bytree=0.4, colsample_bylevel=0.6, total=  25.3s
# [CV] subsample=0.5, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=10, learning_rate=0.1, gamma=0, colsample_bytree=0.4, colsample_bylevel=0.6
# [CV]  subsample=0.5, reg_lambda=5.0, n_estimators=100, min_child_weight=10.0, max_depth=10, learning_rate=0.1, gamma=0, colsample_bytree=0.4, colsample_bylevel=0.6, total=  22.2s
# [CV] subsample=1.0, reg_lambda=0.1, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.1, gamma=0, colsample_bytree=0.5, colsample_bylevel=1.0
# [CV]  subsample=1.0, reg_lambda=0.1, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.1, gamma=0, colsample_bytree=0.5, colsample_bylevel=1.0, total=  42.4s
# [CV] subsample=1.0, reg_lambda=0.1, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.1, gamma=0, colsample_bytree=0.5, colsample_bylevel=1.0
# [CV]  subsample=1.0, reg_lambda=0.1, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.1, gamma=0, colsample_bytree=0.5, colsample_bylevel=1.0, total=  42.3s
# [CV] subsample=0.9, reg_lambda=1.0, n_estimators=50, min_child_weight=10.0, max_depth=15, learning_rate=0.001, gamma=0.25, colsample_bytree=0.6, colsample_bylevel=0.8
# [CV]  subsample=0.9, reg_lambda=1.0, n_estimators=50, min_child_weight=10.0, max_depth=15, learning_rate=0.001, gamma=0.25, colsample_bytree=0.6, colsample_bylevel=0.8, total=  31.2s
# [CV] subsample=0.9, reg_lambda=1.0, n_estimators=50, min_child_weight=10.0, max_depth=15, learning_rate=0.001, gamma=0.25, colsample_bytree=0.6, colsample_bylevel=0.8
# [CV]  subsample=0.9, reg_lambda=1.0, n_estimators=50, min_child_weight=10.0, max_depth=15, learning_rate=0.001, gamma=0.25, colsample_bytree=0.6, colsample_bylevel=0.8, total=  31.5s
# [CV] subsample=0.5, reg_lambda=10.0, n_estimators=150, min_child_weight=3.0, max_depth=20, learning_rate=0.1, gamma=0.5, colsample_bytree=0.7, colsample_bylevel=0.9
# [CV]  subsample=0.5, reg_lambda=10.0, n_estimators=150, min_child_weight=3.0, max_depth=20, learning_rate=0.1, gamma=0.5, colsample_bytree=0.7, colsample_bylevel=0.9, total= 2.1min
# [CV] subsample=0.5, reg_lambda=10.0, n_estimators=150, min_child_weight=3.0, max_depth=20, learning_rate=0.1, gamma=0.5, colsample_bytree=0.7, colsample_bylevel=0.9
# [CV]  subsample=0.5, reg_lambda=10.0, n_estimators=150, min_child_weight=3.0, max_depth=20, learning_rate=0.1, gamma=0.5, colsample_bytree=0.7, colsample_bylevel=0.9, total= 2.3min
# [CV] subsample=0.9, reg_lambda=10.0, n_estimators=50, min_child_weight=1.0, max_depth=10, learning_rate=0.2, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=0.7
# [CV]  subsample=0.9, reg_lambda=10.0, n_estimators=50, min_child_weight=1.0, max_depth=10, learning_rate=0.2, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=0.7, total=  15.7s
# [CV] subsample=0.9, reg_lambda=10.0, n_estimators=50, min_child_weight=1.0, max_depth=10, learning_rate=0.2, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=0.7
# [CV]  subsample=0.9, reg_lambda=10.0, n_estimators=50, min_child_weight=1.0, max_depth=10, learning_rate=0.2, gamma=1.0, colsample_bytree=0.4, colsample_bylevel=0.7, total=  15.7s
# [CV] subsample=1.0, reg_lambda=100.0, n_estimators=50, min_child_weight=7.0, max_depth=15, learning_rate=0.01, gamma=1.0, colsample_bytree=0.5, colsample_bylevel=1.0
# [CV]  subsample=1.0, reg_lambda=100.0, n_estimators=50, min_child_weight=7.0, max_depth=15, learning_rate=0.01, gamma=1.0, colsample_bytree=0.5, colsample_bylevel=1.0, total=  32.8s
# [CV] subsample=1.0, reg_lambda=100.0, n_estimators=50, min_child_weight=7.0, max_depth=15, learning_rate=0.01, gamma=1.0, colsample_bytree=0.5, colsample_bylevel=1.0
# [CV]  subsample=1.0, reg_lambda=100.0, n_estimators=50, min_child_weight=7.0, max_depth=15, learning_rate=0.01, gamma=1.0, colsample_bytree=0.5, colsample_bylevel=1.0, total=  32.8s
# [CV] subsample=1.0, reg_lambda=100.0, n_estimators=100, min_child_weight=3.0, max_depth=10, learning_rate=0.2, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.7
# [CV]  subsample=1.0, reg_lambda=100.0, n_estimators=100, min_child_weight=3.0, max_depth=10, learning_rate=0.2, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.7, total=  41.6s
# [CV] subsample=1.0, reg_lambda=100.0, n_estimators=100, min_child_weight=3.0, max_depth=10, learning_rate=0.2, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.7
# [CV]  subsample=1.0, reg_lambda=100.0, n_estimators=100, min_child_weight=3.0, max_depth=10, learning_rate=0.2, gamma=1.0, colsample_bytree=0.6, colsample_bylevel=0.7, total=  41.7s
# [CV] subsample=0.6, reg_lambda=100.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.1, gamma=0.25, colsample_bytree=0.9, colsample_bylevel=0.4
# [CV]  subsample=0.6, reg_lambda=100.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.1, gamma=0.25, colsample_bytree=0.9, colsample_bylevel=0.4, total=  36.2s
# [CV] subsample=0.6, reg_lambda=100.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.1, gamma=0.25, colsample_bytree=0.9, colsample_bylevel=0.4
# [CV]  subsample=0.6, reg_lambda=100.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.1, gamma=0.25, colsample_bytree=0.9, colsample_bylevel=0.4, total=  36.3s
# [CV] subsample=0.9, reg_lambda=10.0, n_estimators=100, min_child_weight=7.0, max_depth=20, learning_rate=0.3, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.9
# [CV]  subsample=0.9, reg_lambda=10.0, n_estimators=100, min_child_weight=7.0, max_depth=20, learning_rate=0.3, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.9, total= 2.4min
# [CV] subsample=0.9, reg_lambda=10.0, n_estimators=100, min_child_weight=7.0, max_depth=20, learning_rate=0.3, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.9
# [CV]  subsample=0.9, reg_lambda=10.0, n_estimators=100, min_child_weight=7.0, max_depth=20, learning_rate=0.3, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.9, total= 2.4min
# [CV] subsample=0.6, reg_lambda=0.1, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.1, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.4
# [CV]  subsample=0.6, reg_lambda=0.1, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.1, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.4, total=  38.7s
# [CV] subsample=0.6, reg_lambda=0.1, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.1, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.4
# [CV]  subsample=0.6, reg_lambda=0.1, n_estimators=150, min_child_weight=1.0, max_depth=6, learning_rate=0.1, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.4, total=  38.7s
# [CV] subsample=0.6, reg_lambda=50.0, n_estimators=150, min_child_weight=7.0, max_depth=15, learning_rate=0.2, gamma=0, colsample_bytree=0.5, colsample_bylevel=0.6
# [CV]  subsample=0.6, reg_lambda=50.0, n_estimators=150, min_child_weight=7.0, max_depth=15, learning_rate=0.2, gamma=0, colsample_bytree=0.5, colsample_bylevel=0.6, total=  53.1s
# [CV] subsample=0.6, reg_lambda=50.0, n_estimators=150, min_child_weight=7.0, max_depth=15, learning_rate=0.2, gamma=0, colsample_bytree=0.5, colsample_bylevel=0.6
# [CV]  subsample=0.6, reg_lambda=50.0, n_estimators=150, min_child_weight=7.0, max_depth=15, learning_rate=0.2, gamma=0, colsample_bytree=0.5, colsample_bylevel=0.6, total=  49.3s
# [CV] subsample=0.6, reg_lambda=1.0, n_estimators=100, min_child_weight=10.0, max_depth=15, learning_rate=0.2, gamma=0.25, colsample_bytree=0.9, colsample_bylevel=0.7
# [CV]  subsample=0.6, reg_lambda=1.0, n_estimators=100, min_child_weight=10.0, max_depth=15, learning_rate=0.2, gamma=0.25, colsample_bytree=0.9, colsample_bylevel=0.7, total= 1.1min
# [CV] subsample=0.6, reg_lambda=1.0, n_estimators=100, min_child_weight=10.0, max_depth=15, learning_rate=0.2, gamma=0.25, colsample_bytree=0.9, colsample_bylevel=0.7
# [CV]  subsample=0.6, reg_lambda=1.0, n_estimators=100, min_child_weight=10.0, max_depth=15, learning_rate=0.2, gamma=0.25, colsample_bytree=0.9, colsample_bylevel=0.7, total= 1.1min
# [CV] subsample=1.0, reg_lambda=1.0, n_estimators=50, min_child_weight=7.0, max_depth=15, learning_rate=0.01, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.8
# [CV]  subsample=1.0, reg_lambda=1.0, n_estimators=50, min_child_weight=7.0, max_depth=15, learning_rate=0.01, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.8, total=  49.0s
# [CV] subsample=1.0, reg_lambda=1.0, n_estimators=50, min_child_weight=7.0, max_depth=15, learning_rate=0.01, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.8
# [CV]  subsample=1.0, reg_lambda=1.0, n_estimators=50, min_child_weight=7.0, max_depth=15, learning_rate=0.01, gamma=0, colsample_bytree=1.0, colsample_bylevel=0.8, total=  49.8s
# [CV] subsample=0.8, reg_lambda=1.0, n_estimators=100, min_child_weight=7.0, max_depth=6, learning_rate=0.01, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.4
# [CV]  subsample=0.8, reg_lambda=1.0, n_estimators=100, min_child_weight=7.0, max_depth=6, learning_rate=0.01, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.4, total=  26.4s
# [CV] subsample=0.8, reg_lambda=1.0, n_estimators=100, min_child_weight=7.0, max_depth=6, learning_rate=0.01, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.4
# [CV]  subsample=0.8, reg_lambda=1.0, n_estimators=100, min_child_weight=7.0, max_depth=6, learning_rate=0.01, gamma=0.25, colsample_bytree=1.0, colsample_bylevel=0.4, total=  26.5s
# [CV] subsample=0.6, reg_lambda=5.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.3, gamma=0, colsample_bytree=0.4, colsample_bylevel=0.9
# [CV]  subsample=0.6, reg_lambda=5.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.3, gamma=0, colsample_bytree=0.4, colsample_bylevel=0.9, total=  35.3s
# [CV] subsample=0.6, reg_lambda=5.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.3, gamma=0, colsample_bytree=0.4, colsample_bylevel=0.9
# [CV]  subsample=0.6, reg_lambda=5.0, n_estimators=100, min_child_weight=1.0, max_depth=10, learning_rate=0.3, gamma=0, colsample_bytree=0.4, colsample_bylevel=0.9, total=  35.2s
# Randomized search time: 1895.4830639362335
# Best score: 0.8702162668034017
# Best params:
# colsample_bylevel: 1.0
# colsample_bytree: 0.5
# gamma: 0
# learning_rate: 0.1
# max_depth: 6
# min_child_weight: 1.0
# n_estimators: 150
# reg_lambda: 0.1
# subsample: 1.0
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 31.6min finished

# %%
xgbmodelfinal = xgb.XGBClassifier(objective='multi:softmax',
                                  num_class = 3, random_state =0, 
                                  eval_metric = 'mlogloss',
                                  colsample_bylevel = 1.0, 
                                  colsample_bytree = 0.5, 
                                  gamma = 0, 
                                  learning_rate = 0.1,
                                  max_depth = 6, 
                                  min_child_weight = 1.0,
                                  n_estimators = 150, 
                                  reg_lambda = 0.1, 
                                  subsample = 1.0)
xgbmodelfinal.fit(X_train,y_train)
xgbf_pred = xgbmodelfinal.predict(X_test)
conf_mat3 = confusion_matrix(y_test, xgbf_pred)
print(conf_mat3)
# Out:
# [[711  32  46]
#  [ 74 418  54]
#  [132  71 178]]

# %%
print(classification_report(y_test, xgbf_pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.78      0.90      0.83       789
#          Low       0.80      0.77      0.78       546
#       Medium       0.64      0.47      0.54       381
#
#     accuracy                           0.76      1716
#    macro avg       0.74      0.71      0.72      1716
# weighted avg       0.75      0.76      0.75      1716

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, xgbmodelfinal.predict_proba(X_test), multi_class='ovr', average = 'weighted')
# Out:
# 0.9047891066630945

# %%
roc_auc_score(y_test, xgbmodel.predict_proba(X_test), multi_class='ovr', average = 'weighted')
# Out:
# 0.9097091196944558

# %%
from sklearn.calibration import CalibratedClassifierCV
clf1 = CalibratedClassifierCV(model) 
clf1.fit(X_train, y_train)
y_proba = clf1.predict_proba(X_test)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, y_proba, multi_class='ovr', average = 'weighted')
# Out:
# 0.9261853595236925
